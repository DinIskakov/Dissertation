# %%
# News from google UK, only titles though

# %%
import pandas as pd

df = pd.read_csv("news_uk_dataset.csv")
df.head()
# Out:
#                                                title  \
# 0  The gift of Gabby: Gabby Logan on politics, mo...
# 1  Politics is full of slippery evasive liars: Af...
# 2  BBC Comedy Blog: Mark Watson responds to Polit...
# 3  German politics set for shake-up as cancer for...
# 4  The Big Question: What is the Tea Party moveme...
#
#                        published                 source  category
# 0  Mon, 11 Jan 2010 08:00:00 GMT  www.independent.co.uk  Politics
# 1  Tue, 26 Jan 2010 08:00:00 GMT    www.dailymail.co.uk  Politics
# 2  Fri, 15 Jan 2010 08:00:00 GMT          www.bbc.co.uk  Politics
# 3  Tue, 26 Jan 2010 08:00:00 GMT  www.independent.co.uk  Politics
# 4  Fri, 22 Jan 2010 08:00:00 GMT  www.independent.co.uk  Politics
